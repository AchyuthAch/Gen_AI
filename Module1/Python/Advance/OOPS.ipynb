# %% [markdown]
# ## Class in Python

# %%
class Human:
    def __init__(self, color, height):
        self.color = color
        self.height = height
    def run(self):
        print("Color name is: ", self.color)
    def walk(self):
        print("Height is:", self.height)

# %%
human1 = Human("yellow", 5.6)

# %%
human1.color
# Out:
# 'yellow'

# %%
human1.height
# Out:
# 5.6

# %% [markdown]
# ## Inheritance
#
# - Parent ==> Base Class
# - Child ==> Dervied Class

# %%
class BaseClass:
    a = 10
    b = 20
    def display(self):
        return "Base Class"

# %%
class DerivedClass(BaseClass):
    c = 20
    d = 30
    def show(self):
        return "Dervived Class"

# %%
check1 = BaseClass()

# %%
print(check1)

# %%
check1.a
# Out:
# 10

# %%
check2 = DerivedClass()

# %%
check2.a
# Out:
# 10

# %%
check2.d
# Out:
# 30

# %% [markdown]
# ## Multi Level Inheritance

# %%
class BaseClass:
    a = 100
    b = 200
    def display(self):
        return "Base Class"

# %%
class DerviedClass(BaseClass):
    c = 300
    d = 400
    def display(self):
        return "Dervied Class"

# %%
class MultiDerviedClass(DerviedClass):
    e = 500
    f = 600
    def display(self):
        return "Multi Dervied Class"

# %%
check4 = BaseClass()

# %%
check4.a
# Out:
# 100

# %%
check5 = DerviedClass()

# %%
check5.b
# Out:
# 200

# %%
check6 = MultiDerviedClass()

# %%
check6.b
# Out:
# 200

# %% [markdown]
# ## Hierarchical Inheritance

# %%
class BaseClass:
    a = 100
    b = 200
    def display(self):
        return "Base Class"

# %%
class DerviedClass1(BaseClass):
    c = 300
    d = 400
    def display(self):
        return "Dervied Class1"

# %%
class DerviedClass2(BaseClass):
    e = 300
    f = 400
    def display(self):
        return "Dervied Class2"

# %%
check1 = BaseClass()

# %%
check1.a
# Out:
# 100

# %%
check2 = DerviedClass1()

# %%
check2.a
# Out:
# 100

# %%
check3 = DerviedClass2()

# %%
check3.c
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 check3.c
#
# AttributeError: 'DerviedClass2' object has no attribute 'c'

# %%
check3.e
# Out:
# 300

# %%
check3.a
# Out:
# 100

# %% [markdown]
# ## Multiple Inheritance

# %%
class Parent1:
    name = "Achyuth"
    def display1(self):
        return "Parent2 Class"

# %%
class Parent2:
    name = "Achuuuu"
    def display1(self):
        return "Parent2 Class"

# %%
class ChildClass(Parent1, Parent2):
    name = "S. Achyuth"
    def display1(self):
        return "Child Class"

# %%
check1 = ChildClass()

# %%
check1.name
# Out:
# 'S. Achyuth'

# %%
check1.display1()
# Out:
# 'Child Class'

# %% [markdown]
# ## Polymorphism

# %%
class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Drive!")

class Boat:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Sail!")

class Plane:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")       #Create a Car object
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat object
plane1 = Plane("Boeing", "747")     #Create a Plane object

for x in (car1, boat1, plane1):
  x.move()
# Out:
# Drive!
# Sail!
# Fly!

# %% [markdown]
# Look at the for loop at the end. Because of polymorphism we can execute the same method for all three classes.

# %% [markdown]
# ## Abstract Method
#
# - “Any class that inherits from me must implement this method.”
# - An abstract method in Python is a method that is declared but contains no implementation (no body). It is meant to be overridden by subclasses

# %%
from abc import ABC, abstractmethod

# %%
class Animal(ABC):#Abstract Class
    @abstractmethod
    def sound(self):#Abstract Method
         pass # no imeplementation

# %%
class Dog():
    def sound(self):
        print("bowbow")

# %%
class Hen():
    def sound(self):
        print("korkorrrr")

# %%
check2 = Dog()

# %%
check2.sound()
# Out:
# bowbow

# %%
check3 = Hen()

# %%
check3.sound()
# Out:
# korkorrrr

# %% [markdown]
# ## Encapsulation & Data Hiding
#
# - Encapsulation is about protecting data inside a class.

# %%
class Demo():
    __a = 10 ###Private
    b = 20
    def __display(self):
        print("Display content")
    def show(self):
        print("Show content")

# %%
demo = Demo()

# %%
demo.a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 demo.a
#
# AttributeError: 'Demo' object has no attribute 'a'

# %%
demo.b
# Out:
# 20

# %%
demo.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 demo.display()
#
# AttributeError: 'Demo' object has no attribute 'display'

# %%
demo.show()
# Out:
# Show content

# %%
class Demo():
    _a = 10 ###Private
    b = 20
    def __display(self):
        print("Display content")
    def _show(self):
        print("Show content")

# %%
demo = Demo()

# %%
demo._a
# Out:
# 10

# %%
demo._show()
# Out:
# Show content

# %%
demo.__display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 demo.__display()
#
# AttributeError: 'Demo' object has no attribute '__display'
