# %% [markdown]
# ## Reserved Keywords
# - keywords.kwlist
# - dir(builtins)
# ## Types of Functions
# - User Defined Functions
# - Lambda functions
# - File IO Operations

# %%
import keyword

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
'function' in keyword.kwlist
# Out:
# False

# %%
import builtins

# %%
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
'def' in dir(builtins) + keyword.kwlist
# Out:
# True

# %%
'function' in dir(builtins) + keyword.kwlist
# Out:
# False

# %%
## User Defined Functions

def my_square(i):
    return i ** 2

# %%
my_square(2)
# Out:
# 4

# %%
## Lambda Functions (A Nameless Functions)

lambda i : i**2
# Out:
# <function __main__.<lambda>(i)>

# %%
import pandas as pd

# %%
my_dict = {'cel': [10, 33, 55, 66]}

# %%
df = pd.DataFrame(my_dict)

# %%
#def temp_to_cel(temp):
#    return temp * 1.8+32

# %%
#temp_to_cel(df)

# %%
#df['cel'].apply(temp_to_cel)

# %%
#df['far'] = df['cel'].apply(temp_to_cel)
#df

# %%
#lambda temp: temp * 1.8+32

# %%
df['cel'].apply(lambda temp:temp*1.8+32)
# Out:
# 0     50.0
# 1     91.4
# 2    131.0
# 3    150.8
# Name: cel, dtype: float64

# %% [markdown]
# ## File IO Operations

# %%
f = open("test.txt")

# %%
print(f.read())
# Out:
# Hello 123
# Hello again 123
# Hellooo bye 123

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.read())

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.read())
# Out:
# Hello 123
# Hello again 123
# Hellooo bye 123

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.readline())
# Out:
# Hello 123

# %%
f.close()

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
f = open("test.txt", 'r+')

# %%
"Helloooooo today 1234556"
# Out:
# 'Helloooooo today 1234556'

# %%
print(f.read())
# Out:
# Hello 123
# Hello again 123
# Hellooo bye 123

# %%
f.close()

# %%
f = open("test.txt", "r+")

# %%
f.read()
# Out:
# 'Hello 123\nHello again 123\nHellooo bye 123Hello AGainnnnn/n Hello AGainnnnn/n Hello AGainnnnn'

# %%
f.write( "/n Hello AGainnnnn")
# Out:
# 18

# %%
f.close()
